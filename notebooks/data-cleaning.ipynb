# %%
import pandas as pd

# %%
campaigns = pd.read_csv('../data/raw/campaigns.csv')
customers = pd.read_csv('../data/raw/customers.csv')
events = pd.read_csv('../data/raw/events.csv')
products = pd.read_csv('../data/raw/products.csv')
transactions = pd.read_csv('../data/raw/transactions.csv')

# %% [markdown]
# # Campaigns
# Columns to be fixed:
# -

# %%
campaigns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   campaign_id    18 non-null     object
#  1   campaign_name  18 non-null     object
#  2   channel        18 non-null     object
#  3   budget         13 non-null     float64
#  4   start_date     18 non-null     object
#  5   end_date       18 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 996.0+ bytes

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  350 non-null    object
#  1   signup_date  350 non-null    object
#  2   country      316 non-null    object
#  3   device_type  350 non-null    object
# dtypes: object(4)
# memory usage: 11.1+ KB
